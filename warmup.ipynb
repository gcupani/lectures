# %% [markdown]
# # Warm-up
#
# In this notebook, you will learn how to load and manipulate data in **FITS** (Flexible Image Transport System) format with Python.
#
# Requisites:
# * a working Python 3.x environment, with **Astropy** (4.0), **Matplotlib** (3.1), and **NumPy** (1.18) installed;
# * a ```utils.py``` file with useful functions;
# * a FITS image frame (e.g. ```sci_2015/Autosave Image -001.fit```).

# %% [markdown]
# ## Quick start with FITS frames
#
# A simple image frame contains only a primary **header data unit (HDU)**. We will use **Astropy** to open it.
#
# > Edit the path to point to *your* frame!

# %%
from astropy.io import fits
                                            
name = 'sci_2015/Autosave Image -001.fit'
hdul = fits.open(name)
hdul.info()
# Out:
# Filename: sci_2015/Autosave Image -001.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      55   (1108, 834)   int16 (rescales to uint16)

# %% [markdown]
# The HDU contains both **metadata** (header) and **data** (image).
# The header is like a dictionary and its elements (**cards** or **keywords**) can be called by name:

# %%
hdr = hdul[0].header
hdr
# Out:
# SIMPLE  =                    T
# BITPIX  =                   16 /8 unsigned int, 16 & 32 int, -32 & -64 real
# NAXIS   =                    2 /number of axes
# NAXIS1  =                 1108 /fastest changing axis
# NAXIS2  =                  834 /next to fastest changing axis
# BSCALE  =   1.0000000000000000 /physical = BZERO + BSCALE*array_value
# BZERO   =   32768.000000000000 /physical = BZERO + BSCALE*array_value
# DATE-OBS= '2015-03-18T19:01:54' /YYYY-MM-DDThh:mm:ss observation start, UT
# EXPTIME =   7.0000000000000000 /Exposure time in seconds
# EXPOSURE=   7.0000000000000000 /Exposure time in seconds
# SET-TEMP=  -20.000000000000000 /CCD temperature setpoint in C
# CCD-TEMP=  -20.056101000000002 /CCD temperature at start of exposure in C
# XPIXSZ  =   16.199999999999999 /Pixel Width in microns (after binning)
# YPIXSZ  =   16.199999999999999 /Pixel Height in microns (after binning)
# XBINNING=                    3 /Binning factor in width
# YBINNING=                    3 /Binning factor in height
# XORGSUBF=                    0 /Subframe X position in binned pixels
# YORGSUBF=                    0 /Subframe Y position in binned pixels
# READOUTM= 'Monochrome' /        Readout mode of image
# FILTER  = 'Luminance' /         Filter used when taking image
# IMAGETYP= 'LIGHT   ' /          Type of image
# FOCUSPOS=                  800 /Focuser position in steps
# FOCUSSSZ=   2.0000000000000000 /Focuser step size in microns
# FOCUSTEM=  -274.00000000000000 /Focuser temperature in deg C
# OBJCTRA = '08 09 36' /          Nominal Right Ascension of center of image
# OBJCTDEC= '+44 28 18' /         Nominal Declination of center of image
# OBJCTALT= ' 84.7258' /          Nominal altitude of center of image
# OBJCTAZ = '100.7240' /          Nominal azimuth of center of image
# OBJCTHA = ' -0.4844' /          Nominal hour angle of center of image
# PIERSIDE= 'WEST    ' /          Side of pier telescope is on
# SITELAT = '45 38 28' /          Latitude of the imaging location
# SITELONG= '13 52 30' /          Longitude of the imaging location
# JD      =   2457100.2929861112 /Julian Date at start of exposure
# JD-HELIO=   2457100.2954186630 /Heliocentric Julian Date at exposure midpoint
# AIRMASS =   1.0042706523597955 /Relative optical path length through atmosphere
# FOCALLEN=   3910.0000000000000 /Focal length of telescope in mm
# APTDIA  =   355.60000610351562 /Aperture diameter of telescope in mm
# APTAREA =   89144.849655475351 /Aperture area of telescope in mm^2
# SWCREATE= 'MaxIm DL Version 5.10' /Name of software that created the image
# OBJECT  = 'SZ_Lyn  '
# TELESCOP= 'SVAS    ' /          telescope used to acquire this image
# INSTRUME= 'C14     ' /          instrument or camera used
# OBSERVER= 'Iafrate '
# NOTES   = '        '
# OBJ_TYPE= 'astro   '
# FLIPSTAT= '        '
# SWOWNER = 'Paolo Santin' /      Licensed owner of software
# INPUTFMT= 'FITS    ' /          Format of file from which image was read
# SWMODIFY= 'MaxIm DL Version 5.12' /Name of software that modified the image
# HISTORY  Edit Flip
# HISTORY  Edit Mirror
# CSTRETCH= 'Medium  ' /          Initial display stretch mode
# CBLACK  =                 1730 /Initial display black level in ADUs
# CWHITE  =                 2228 /Initial display white level in ADUs
# PEDESTAL=                    0 /Correction to add for zero-based ADU

# %%
hdr['EXPTIME']
# Out:
# 7.0

# %% [markdown]
# You can modify keywords and add comments to keywords:

# %%
hdr['OBJECT'], hdr.comments['OBJECT']
# Out:
# ('SZ_Lyn', '')

# %%
hdr['OBJECT'] = 'V* SZ Lyn'
hdr.comments['OBJECT'] = 'Variable Star of delta Sct type'
hdr['OBJECT'], hdr.comments['OBJECT']
# Out:
# ('V* SZ Lyn', 'Variable Star of delta Sct type')

# %% [markdown]
# The image is an **array** and its pixels can be addressed by index:

# %%
img = hdul[0].data
img
# Out:
# array([[2122, 2093, 2054, ..., 2047, 1947, 2011],
#        [2222, 2146, 2102, ..., 1981, 1947, 1952],
#        [2046, 2100, 2137, ..., 1961, 1944, 2049],
#        ...,
#        [1846, 1913, 1921, ..., 1915, 1957, 1844],
#        [1913, 1861, 1840, ..., 1861, 1918, 1865],
#        [1929, 2046, 1875, ..., 1936, 1932, 1856]], dtype=uint16)

# %%
img[0][0]
# Out:
# 2122

# %% [markdown]
# You can of course save your changes (in a new frame, possibly):

# %%
hdul.writeto('new_frame.fits', overwrite=True)
hdul_test = fits.open('new_frame.fits')
hdul_test[0].header['OBJECT']
# Out:
# 'V* SZ Lyn'

# %% [markdown]
# ## Learn how to speak array
#
# An image is (quite obviously) a **2-d matrix** of pixels. You can think of it as an **array of (sub-)arrays**. Each sub-array is a row of pixels. The array of all rows is the whole matrix. ```shape``` gives the size of the matrix (rows times columns).

# %%
img.shape
# Out:
# (834, 1108)

# %% [markdown]
# A sub-array can be called with a single index:

# %%
row0 = img[0]
row0
# Out:
# array([2122, 2093, 2054, ..., 2047, 1947, 2011], dtype=uint16)

# %% [markdown]
# Then you can call an element (or a slice) of the sub-array:

# %%
row0[2]
# Out:
# 2054

# %%
row0[::2]
# Out:
# array([2122, 2054, 2114, 2050, 2091, 2066, 2023, 2013, 2104, 2111, 1973,
#        1927, 1947, 1978, 1884, 1970, 1992, 1983, 1970, 1897, 1852, 1958,
#        1899, 1902, 1953, 1989, 1991, 1882, 1919, 1949, 1905, 1898, 1841,
#        1922, 1897, 1699, 1792, 1873, 1803, 1904, 1837, 1870, 1795, 1910,
#        1774, 1821, 1867, 1713, 1815, 1866, 1814, 1820, 1822, 1812, 1862,
#        1774, 1775, 1831, 1874, 1794, 1869, 1781, 1806, 1779, 1944, 1800,
#        1821, 1808, 1875, 1840, 1795, 1836, 1874, 1812, 1893, 1836, 1887,
#        1765, 1890, 1861, 1854, 1828, 1759, 1837, 1796, 1882, 1890, 1824,
#        1924, 1829, 1854, 1869, 1896, 1884, 1871, 1841, 1863, 1876, 1846,
#        1869, 1827, 1916, 1850, 1916, 1813, 1843, 1789, 1985, 1896, 1908,
#        1865, 1831, 1776, 1799, 1837, 1882, 1818, 1840, 1831, 1950, 1769,
#        1833, 1829, 1906, 1938, 1864, 1839, 1852, 1885, 1872, 1908, 1826,
#        1938, 1852, 1851, 1836, 1799, 1799, 1824, 1943, 1867, 1909, 1984,
#        1808, 1860, 1867, 1931, 1813, 1899, 1972, 1910, 1871, 1931, 1860,
#        1952, 1832, 1909, 1906, 1907, 1817, 1850, 1977, 1933, 2037, 1835,
#        1859, 1912, 1855, 1973, 1929, 1918, 1854, 1932, 1864, 1958, 2016,
#        1983, 1937, 1896, 1947], dtype=uint16)

# %% [markdown]
# You can do the same with two indices:

# %%
img[0][2], img[0,2]
# Out:
# (2054, 2054)

# %% [markdown]
# Notice that using two sets of brackets is *not* the same as using one. Each set of brackets is applied *after* the previous one, while operations within brackets are performed *all at once*.

# %%
img[0][:], img[0,:]
# Out:
# (array([2122, 2093, 2054, ..., 2047, 1947, 2011], dtype=uint16),
#  array([2122, 2093, 2054, ..., 2047, 1947, 2011], dtype=uint16))

# %%
img[:][0], img[:,0]
# Out:
# (array([2122, 2093, 2054, ..., 2047, 1947, 2011], dtype=uint16),
#  array([2122, 2222, 2046, 2155, 2047, 2073, 2108, 2046, 2069, 2037, 2098,
#         1981, 2139, 2095, 2116, 2063, 2050, 1973, 1949, 2006, 2067, 2048,
#         2152, 2102, 1946, 2072, 1997, 2041, 1998, 2018, 2013, 1937, 1966,
#         1985, 1953, 1981, 2110, 2050, 1963, 2142, 1952, 1975, 2021, 2047,
#         1967, 2003, 1998, 2077, 2024, 1957, 1906, 1900, 2022, 2040, 1892,
#         1979, 2038, 2030, 2042, 2083, 2004, 1918, 1918, 1922, 2074, 1995,
#         1992, 1946, 1943, 2000, 2006, 2023, 1944, 1924, 1993, 1919, 1996,
#         2087, 1869, 2029, 1966, 1989, 2066, 1929, 1975, 1917, 1993, 1992,
#         2040, 1951, 1941, 1907, 1944, 1974, 1924, 2079, 1977, 2076, 1984,
#         2032, 1915, 2018, 1970, 1923, 2077, 2029, 2018, 2008, 1936, 1974,
#         1961, 1891, 2046, 1944, 1981, 1986, 2049, 1979, 2072, 1870, 2013,
#         1941, 1899, 1976, 1971, 1953, 2021, 2048, 1966, 1936, 1917, 1956,
#         1954, 2030, 1986, 1919, 1915, 2002, 2090, 1863, 1931, 1882, 1952,
#         1915, 1930, 2010, 2032, 1994, 2004, 1990, 1964, 1947, 1951, 1947,
#         1980, 1981, 2004, 2099, 1955, 1926, 1878, 1947, 2071, 1963, 1966,
#         1878, 1933, 1922, 2073, 1999, 1998, 1931, 1897, 1936, 1892, 1925,
#         1978, 1850, 1909, 1896, 1787, 1927, 1888, 1930, 1894, 1954, 2081,
#         1910, 1984, 1880, 1930, 1877, 1797, 2038, 2074, 1974, 1920, 1963,
#         1955, 1888, 1939, 1886, 1965, 1882, 1970, 1961, 1969, 1868, 1968,
#         1896, 1926, 1936, 1887, 2033, 1940, 1891, 1980, 1963, 1895, 1944,
#         1923, 1867, 1920, 1896, 1916, 1884, 1863, 1857, 1959, 1829, 2058,
#         1927, 1911, 1934, 1893, 1915, 1935, 1974, 1981, 1963, 1925, 1975,
#         1972, 1907, 1930, 1932, 1973, 2033, 1874, 1960, 1837, 1901, 1910,
#         1937, 1943, 1982, 1910, 1940, 1981, 2017, 1941, 1902, 1900, 1923,
#         1963, 1937, 1896, 1958, 1954, 1957, 1844, 1924, 1917, 1972, 1888,
#         1864, 1930, 1896, 1978, 1948, 1870, 1921, 1889, 1869, 1901, 1960,
#         1863, 1814, 1913, 1935, 1861, 1985, 1875, 1970, 1928, 1969, 1959,
#         1798, 1995, 1825, 1911, 1903, 1999, 1898, 1958, 2002, 1966, 1969,
#         1954, 1950, 1943, 1867, 1967, 1913, 1885, 1902, 1912, 1946, 1938,
#         1921, 1887, 1956, 1917, 1794, 1918, 1902, 1932, 1816, 1894, 1867,
#         1874, 1936, 1911, 1924, 1999, 1936, 1907, 1922, 1898, 1915, 1944,
#         1913, 1894, 1971, 1950, 1995, 1980, 1902, 1940, 1888, 1938, 1956,
#         1919, 2035, 1882, 1858, 1995, 1967, 1882, 1858, 1919, 1974, 1973,
#         1932, 1881, 1970, 1955, 1955, 1992, 1909, 1880, 1875, 1967, 1883,
#         1858, 1940, 1863, 1862, 1930, 1944, 1877, 1925, 1772, 1894, 1945,
#         1814, 1894, 1955, 2008, 1860, 1984, 1888, 1916, 1919, 1980, 1965,
#         1906, 1910, 1880, 1883, 1976, 1938, 1854, 1856, 1904, 1995, 1903,
#         1911, 1903, 1899, 1907, 1919, 1966, 1843, 1818, 1905, 1867, 1904,
#         1936, 1909, 1842, 1876, 1871, 1934, 1900, 1960, 1822, 1915, 1932,
#         1909, 1879, 1785, 1963, 1884, 1867, 1907, 1905, 1941, 1845, 1847,
#         1935, 1805, 1893, 1896, 1826, 1872, 1925, 1863, 1951, 1937, 1791,
#         1946, 1850, 1809, 1915, 1917, 1822, 1888, 1917, 1904, 1937, 1820,
#         1877, 1882, 1877, 1900, 1897, 1846, 1846, 1913, 1929], dtype=uint16))

# %% [markdown]
# ## A plot is worth a thousand printouts
#
# We will use **Matplotlib** to visualize data.

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

# %% [markdown]
# To extract a sub-image, you can slice the array:

# %%
sub_img = img[510:530, 630:660]
plt.imshow(sub_img)
plt.show()

# %% [markdown]
# You can use ```figure``` to create a new figure instead of overplotting it. ```show``` is used just at the end to display all figures. Compare:

# %%
plt.imshow(img)
plt.imshow(sub_img)
...
plt.show()  # Only last image is shown

# %%
plt.figure()  # First figure
plt.imshow(img)
plt.figure()  # Second figure
plt.imshow(sub_img)
...
plt.show()  # All images are shown in separate figures

# %% [markdown]
# In ```utils.py``` you can find a useful function to plot images with proper formatting. This is how it is used:

# %%
from utils import plot_img

plot_img(img)
plot_img(sub_img)
plt.show()

# %% [markdown]
# ```imshow``` works only with 2-d matrices (images). To plot simple arrays (like image rows or columns), use ```plot``` for a continuous plot or ```scatter``` for a scatter plot:

# %%
row = sub_img[7,:]
col = sub_img[:,13]
row_range = range(sub_img.shape[1])
col_range = range(sub_img.shape[0])
plt.figure()
plt.plot(row_range, row)
plt.figure()
plt.scatter(col_range, col)
plt.show()

# %% [markdown]
# Also in this case, you can find a suitable function in ```utils.py```, which can be also used to overplot several arrays on top of each other:

# %%
from utils import plot_graph

plot_graph(row, xlabel='x pixel', ylabel='ADU')
plot_graph(col, mode='scatter', new=False)
plt.show()

# %% [markdown]
# > **Your turn now**: write the code to extract a 11x11-pixel window centered in (7, 13) from ```sub_img``` and to plot all the rows and columns of this new sub image.

# %% [markdown]
# > **Only for the brave**: using Python lists, write a function to swap the x and y axes of an image. **Tip**: to shorten the computation time, try swapping ```sub_img``` instead of ```img```.

# %% [markdown]
# ## And now for some “serious”data crunching
#
# We will use **NumPy** and **SciPy** to do statistics on arrays. A simple test case: find the global maximum of an array (remember from analysis: the *maximum point* is the index where the array reaches its *maximum value*).

# %%
import numpy as np

row_mv = np.max(row) 
row_mp = np.argmax(row)
row_mp, row_mv
# Out:
# (13, 37914)

# %%
plt.plot(range(len(row)), row)
plt.scatter(row_mp, row_mv, color='r') 
plt.show()

# %%
plot_graph(row)
plot_graph(row_mp, row_mv, new=False, mode='scatter', xlabel='x pixel', ylabel='ADU', color='r')

# %% [markdown]
# You can use ```where``` to check the result:

# %%
np.where(row==row_mv)
# Out:
# (array([13]),)

# %% [markdown]
# In the case of an image (which is, as we said, a 2-d matrix), ```argmax``` returns the maximum point of the *flattened* array (i.e. the array obtained by concatenating all rows):

# %%
sub_img_mv = np.max(sub_img)
sub_img_mp = np.argmax(sub_img)
sub_img_mv, sub_img_mp
# Out:
# (37914, 223)

# %% [markdown]
# To obtain a 2-tuple with the row and column of the maximum point, you have to ‘unravel’ the result onto the shape of the array:

# %%
(sub_img_mrow, sub_img_mcol) = np.unravel_index(np.argmax(sub_img), sub_img.shape)
sub_img_mrow, sub_img_mcol
# Out:
# (7, 13)

# %% [markdown]
# Also in this case, you can check the result with ```where```:

# %%
np.where(sub_img==sub_img_mv)
# Out:
# (array([7]), array([13]))

# %% [markdown]
# You can find a function ```extrema``` implementing this approach for either maxima and minima in ```utils.py```. Note that the output of this function is a (x,y) tuple and is accepted as such by ```plot_graph```:

# %%
from utils import extrema

plot_img(sub_img)
plot_graph(extrema(sub_img), new=False, mode='scatter', color='r')

# %% [markdown]
# > **Your turn now**: with help from the NumPy Reference (https://docs.scipy.org/doc/numpy-1.16.1/reference/), compute the arithmetic mean and the median of ```sub_img```. What can we infer from the difference between the two values? **Extra points**: compute the median of each rows of ```img``` separately and plot all the values as a function of the row index.
